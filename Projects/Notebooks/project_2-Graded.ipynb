# %% [markdown]
# # Project 2
# ## Step 1: Exploring your data.
#
# ##### Load your data in using Pandas and start to explore. Save all of your early exploration code here and include in your final submission.

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook

matplotlib.style.use('ggplot')

# %%
#Reading the Billboard CSV file into DataFrame
#db = pd.read_csv("C:\\DSI\\SatyaSagi\\Projects\\Assets\\billboard.csv")
db = pd.read_csv("../Assets/billboard.csv")
#Checking the values of db
db
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %% [markdown]
# ##### Write a brief description of your data, and any interesting observations you've made thus far.

# %%
db.dtypes
# Out:
# year                 int64
# artist.inverted     object
# track               object
# time                object
# genre               object
# date.entered        object
# date.peaked         object
# x1st.week            int64
# x2nd.week          float64
# x3rd.week          float64
# x4th.week          float64
# x5th.week          float64
# x6th.week          float64
# x7th.week          float64
# x8th.week          float64
# x9th.week          float64
# x10th.week         float64
# x11th.week         float64
# x12th.week         float64
# x13th.week         float64
# x14th.week         float64
# x15th.week         float64
# x16th.week         float64
# x17th.week         float64
# x18th.week         float64
# x19th.week         float64
# x20th.week         float64
# x21st.week         float64
# x22nd.week         float64
# x23rd.week         float64
#                     ...
# x47th.week         float64
# x48th.week         float64
# x49th.week         float64
# ...

# %% [markdown]
# The dataframe represents data of Billboard Top 100 chart containing columns for Year, Artist, Genre, Track, Time, Data Entered, Date Peaked and 76 week columns which represent ranking.

# %%
from IPython.display import Image
Image(filename="../Assets/Data Dictionary.jpg")

#JB this doesn't give me any useful info.

# %% [markdown]
# ## Step 2: Clean your data.

# %% [markdown]
# ##### Do some rudimentary cleaning. Rename any columns that are poorly named, shorten any strings that may be too long, fill in any missing values. Explain your rationale for the way you choose to "impute" the missing data.

# %%
#Commented the code below to test the regular Pandas in the later cel
#Code to replace certain characters from columns
#dbcolumns = dbOne.columns

#def replaceChars(string):
#  newStr = ""
#  for x in ["rd","th","x"]:
#     newStr = string.replace(x, "")
#  return newStr
  
#def ColVals(columnName):
#  if "week" in columnName:
#    newVal = columnName.split(".") # this makes an array of two elements 
#    weekCol = newVal[1]
#    otherVal = replaChars( newVal[0] )
#    return weekCol + "_" + otherVal
    
#newColumns = map(ColVals, dbcolumns)

#db.columns = newColumns

# %%
#Renaming the Column Names
#import re
#1. Replacing the period ('.') in the column names
dbOne = db.rename(columns=lambda x: x.replace('.', ' '), inplace=True)
#2. Replacing the character 'x' from columns
dbOne = db.rename(columns=lambda x: x.replace('x', ''), inplace=True)
#3 Make the first letter as capitals
dbOne = db.rename(columns=lambda x: x.title(), inplace=True)
#4 Replace 'St'
dbOne = db.rename(columns=lambda x: x.replace('St',''), inplace=True)
#5 Replacing 'Nd'
dbOne = db.rename(columns=lambda x: x.replace('Nd',''), inplace=True)
#6 Replacing "Rd"
dbOne = db.rename(columns=lambda x: x.replace('Rd',''), inplace=True)
#6 Replacing 'Th'
dbOne = db.rename(columns=lambda x: x.replace('Th',''), inplace=True)
#7 Replace 'Week'
dbOne = db.rename(columns=lambda x: x.replace('Week',''), inplace=True)
#8 Replace 'Inverted' with blank in place of column 'Artist Inverted'
dbOne = db.rename(columns=lambda x: x.replace('Artist Inverted','Artist'))
#Output with the refined column names
dbOne
# Out:
#      Year               Artist  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
#Stripping Track column
dbTwo = dbOne
dbOne['Track'] = dbOne['Track'].apply(lambda x: x[ : 20])
dbTwo
# Out:
#      Year               Artist                 Track  Time        Genre  \
# 0    2000      Destiny's Child  Independent Women Pa  3:38         Rock
# 1    2000              Santana          Maria, Maria  4:18         Rock
# 2    2000        Savage Garden    I Knew I Loved You  4:07         Rock
# 3    2000              Madonna                 Music  3:45         Rock
# 4    2000  Aguilera, Christina  Come On Over Baby (A  3:38         Rock
# 5    2000                Janet  Doesn't Really Matte  4:17         Rock
# 6    2000      Destiny's Child           Say My Name  4:31         Rock
# 7    2000    Iglesias, Enrique           Be With You  3:36        Latin
# 8    2000                Sisqo            Incomplete  3:52         Rock
# 9    2000             Lonestar                Amazed  4:25      Country
# 10   2000               N'Sync      It's Gonna Be Me  3:10         Rock
# 11   2000  Aguilera, Christina     What A Girl Wants  3:18         Rock
# ...

# %%
#Replacing NaN values with 0
#dbOne.fillna(0, inplace=True)
#dbOne

# %% [markdown]
# ##### Using Pandas' built in `melt` function, pivot the weekly ranking data to be long rather than wide. As a result, you will have removed the 72 'week' columns and replace it with two: Week and Ranking. There will now be multiple entries for each song, one for each week on the Billboard rankings.

# %%
#Get Column Names into a list
dbColumns = list(dbOne)
dbColumns
#Use Column Names list to use first 8 columns as the standard columns and make melt on the Weeks and Rank
dbMelt = pd.melt(dbOne, id_vars = dbColumns[0:7], var_name = 'Week', value_name = 'Rank').dropna()
dbMelt['Rank'] = dbMelt['Rank'].astype(int)
dbMelt['Week'] = dbMelt.Week.astype(int)
dbMelt

#JB great structure!
# Out:
#        Year               Artist                 Track  Time    Genre  \
# 0      2000      Destiny's Child  Independent Women Pa  3:38     Rock
# 1      2000              Santana          Maria, Maria  4:18     Rock
# 2      2000        Savage Garden    I Knew I Loved You  4:07     Rock
# 3      2000              Madonna                 Music  3:45     Rock
# 4      2000  Aguilera, Christina  Come On Over Baby (A  3:38     Rock
# 5      2000                Janet  Doesn't Really Matte  4:17     Rock
# 6      2000      Destiny's Child           Say My Name  4:31     Rock
# 7      2000    Iglesias, Enrique           Be With You  3:36    Latin
# 8      2000                Sisqo            Incomplete  3:52     Rock
# 9      2000             Lonestar                Amazed  4:25  Country
# 10     2000               N'Sync      It's Gonna Be Me  3:10     Rock
# 11     2000  Aguilera, Christina     What A Girl Wants  3:18     Rock
# ...

# %%
#Sort the Melted DataFrame..
dbMeltSortByTrack = dbMelt.sort_values(['Track','Week'], ascending=True)
#Deleting Year column as it is only year 2000
dbMeltSortByTrack.drop('Year',axis=1,inplace=True)
dbMeltSortByTrack

#JB sort artist first
# Out:
#              Artist                 Track  Time    Genre Date Entered  \
# 47            Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 364           Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 681           Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 998           Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 1315          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 1632          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 1949          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 2266          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 2583          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 2900          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 3217          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# 3534          Nelly  (Hot S**t) Country G  4:17      Rap   2000-04-29
# ...

# %%
#Show the ranking for a song for an artist per week'
dbPivot = pd.pivot_table(dbMeltSortByTrack, index=['Artist','Track','Rank'])
                        
dbPivot
# Out:
#                                                 Week
# Artist          Track                Rank
# 2 Pac           Baby Don't Cry (Keep 72     3.000000
#                                      77     4.000000
#                                      82     2.000000
#                                      87     3.000000
#                                      94     6.000000
#                                      99     7.000000
# 2Ge+her         The Hardest Part Of  87     2.000000
#                                      91     1.000000
#                                      92     3.000000
# 3 Doors Down    Kryptonite           3     33.000000
#                                      4     30.600000
#                                      5     31.500000
#                                      6     24.000000
#                                      7     22.000000
#                                      9     38.500000
#                                      12    21.000000
# ...

# %%
#dbPivot.to_csv('C:\\DSI\\SatyaSagi\\Projects\\Assets\\billboard Tableau.csv', index_Name=True)

# %% [markdown]
# ## Step 3: Visualize your data.

# %% [markdown]
# ##### Using a plotting utility of your choice (Tableau or python modules or both), create visualizations that will provide context to your data. There is no minimum or maximum number of graphs you should generate, but there should be a clear and consistent story being told. Give insights to the distribution, statistics, and relationships of the data.

# %%
# Making separate Data Frame
dScatter = dbMeltSortByTrack
# Making subset of Genres 
dScatter['GenreSub'] = np.select([dScatter.Genre == 'Rock', dScatter.Genre == 'Rap', dScatter.Genre == 'Country'],
                        ['Rock','Rap','Country'],'Troubles')
# Fixing colors for each Genre
for color, label in zip('rbgy', ['Rock','Rap','Country','Troubles']):
   GenreSub = dScatter[dScatter.GenreSub == label]
   plt.scatter(GenreSub.Week,GenreSub.Rank, s=25,c=color, label=str(label))
plt.xlabel('Week')
plt.ylabel('Rank')
plt.gca().invert_yaxis()

plt.legend()

#JB what are TROUBLES??? LOL
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The above plot shows major 3 and other Genres with their weekly ranking

# %%
#Group the DataFrame by Genre to find out weekly count
dbGroupBy = dbMeltSortByTrack.groupby("Genre")

#Making Series for Genres and Counts separately
genres = []
counts = []

for name, group in dbGroupBy:
    genres.append( name )
    counts.append( len(group) )

#Regrouping Genres and Counts together into DataFrame    
dfToPlot = pd.DataFrame( {"genre" : genres, "counts": counts } )
#Plotting the barchart
dfToPlot.plot(kind = "bar", x = "genre", y = "counts")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The above graph shows Total count of Genres in the Billboard's Top 100. Rock is highest Genre that appeared in Billboard charts and Country is the next best Genre followed by Rap.

# %%
dbGrpByArtist = dbMeltSortByTrack[dbMeltSortByTrack.Rank <= 20].groupby("Artist")


artists = []
ranks = []

for name, rank in dbGrpByArtist:
    artists.append( name )
    ranks.append( len(rank) )

dfArtist = pd.DataFrame( { 'Artist' : artists, 'Rank' : ranks } )


dfArtist.plot(kind = "bar", x = "Artist", y = "Rank")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The above bar chart shows the artists with songs count below the rank 20 for the year 2000.

# %%
#JB so what is this telling me?

# %% [markdown]
# ## Step 4: Create a Problem Statement.
#
# ##### Having explored the data, come up with a problem statement for this data set. You can feel free to introduce data from any other source to support your problem statement, just be sure to provide a link to the origin of the data. Once again- be creative!

# %% [markdown]
# The data set contains 72 Week columns against 52 weeks in a year.
# Most of the weekly columns have null values.
# Some tracks have data until 64th week.
# Column naming of data set is improper.
# The data is improperly orgainzed.
# This data set may not give correct result.

# %%
#JB that is one problem, but let's assume this is all we have. "Having explored the data" what is the business problem?

# %% [markdown]
# ## Step 5: Brainstorm your Approach.
# ##### In bullet-list form, provide a proposed approach for evaluating your problem statement. This can be somewhat high-level, but start to think about ways you can massage the data for maximum efficacy.

# %% [markdown]
# 1. Get the data into data frame.
# 2. Rename the column names to make them more readable.
# 3. Delete or Drop the columns with null values and improper data.
# 4. Re-arrange the data set to use the more effectivey.
# 5. Identify key columns with which the data can be represented.

# %% [markdown]
# ## Step 6: Create a blog post with your code snippets and visualizations.
# ##### Data Science is a growing field, and the Tech industry thrives off of collaboration and sharing of knowledge. Blogging is a powerful means for pushing the needle forward in our field. Using your blogging platform of choice, create a post describing each of the 5 steps above. Rather than writing a procedural text, imagine you're describing the data, visualizations, and conclusions you've arrived at to your peers. Aim for a minimum of 500 words.

# %% [markdown]
#                                 Billboard Top 100 Chart
#
# Introduction -
#
# A team of General Assembly Training Institute, Atlanta carried out the analysis of Billboard Top 100 chart for the year 2000. The team has applied DataScience tool Python programming to analyse different Genres and Artists who stood in top in Billboard.
# After active exploration of the data, the team laid out different analysis independently by focusing on different Genres, Artists and their performance in weekly rankings. The team gave an insight into the famous singers (artists) who maintained top 20 ranking status in the charts.
#
# Genres Visualization -
# Above visualizations concentrate on showing top genres and top artists performance over the year.
# The scatter plot shows the performance of the top genres Rock, Rap and Country per week vs other genres.
#
# The bar chart shows the genres count in a year. The drawing reflects the genres Rock and Country as the most popular among the Billboard charts.
#
# Another bar chart shows the artists who have maintained top 20 rankings in the Billboard. The chart reflects the top artists consistent performance through out the years.
#
# How did we accomplish this? -
# We leveraged the programming language Python's map plot visualization capabilities to draw comparisons between Generes and Artists. MatPlotLib library provides good visualizations. We used the Billboard's top 100 chart for the year 2000 as a sample to come up with conclusions about Genres and Artist's popularity.

# %%
#JB need more results/conclusions!

# %% [markdown]
# ## BONUS: The Content Managers working for the Podcast Publishing Company have recognized you as a thought leader in your field. They've asked you to pen a white paper (minimum 500 words) on the subject of 'What It Means To Have Clean Data'. This will be an opinion piece read by a wide audience, so be sure to back up your statements with real world examples or scenarios.
#
# ##### Hint: To get started, look around on the internet for articles, blog posts, papers, youtube videos, podcasts, reddit discussions, anything that will help you understand the challenges and implications of dealing with big data. This should be a personal reflection on everything you've learned this week, and the learning goals that have been set out for you going forward.

# %% [markdown]
# Score | 15/24
# ----- | ------
# Identify: Problem Statement / Hypothesis	| 1
# Identify: Risks & Assumptions				| 2
# Acquire: Import Data Using Pandas			| 3
# Parse: Perform EDA Using Pandas				| 2
# Mine: Plot Data & Generate Visuals			| 2
# Mine: Determine Correlations				| 2
# Refine: Evaluate Findings				    | 1
# Present: Describe Results in Blog Post		| 2
# Bonus! Present: Write a short White Paper	| 0
