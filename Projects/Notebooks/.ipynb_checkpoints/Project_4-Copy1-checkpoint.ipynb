# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import urllib2
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
## YOUR CODE HERE
#resultIndeed = urllib2.urlopen(URL).read()
soup = BeautifulSoup((requests.get(URL)).text)
letters = soup.find_all("div", {"class": " row result"}) 
for letter in letters: 
    print letter.prettify() 

def extract_location_from_result(result): 
    location = []   
    for i in result: 
        location.append(i.find ("span", {"class": "location"}).text) 
        return location 
    
def extract_company_from_result(result): 
    company = [] 
    for i in result: 
        company.append(i.find ("span", {"class": "company"}).text.strip()) 
        return company 
def extract_summary_from_result(result): 
    summary =[] 
    for i in result: 
        summary.append(i.find ("span", {"class": "summary"}).text.strip()) 
        return summary 
#def extract_salary_from_result(result): 
#    return result.find ("span", {"class": "location"})  
location = extract_location_from_result(letters) 
company = extract_company_from_result(letters) 
summary = extract_summary_from_result(letters) 
print location
# Out:
# <div class=" row result" data-jk="5b8a65b6982893bf" data-tn-component="organicJob" id="p_5b8a65b6982893bf" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_5b8a65b6982893bf">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5b8a65b6982893bf&amp;fccid=6ae0e4a8a0a337cd" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Placeiq?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=5b8a65b6982893bf&amp;jcid=6ae0e4a8a0a337cd" target="_blank">
#     PlaceIQ
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Placeiq/reviews?jcid=6ae0e4a8a0a337cd" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=5b8a65b6982893bf');" target="_blank" title="Placeiq reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    4.7
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 55.199997px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    3 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       <b>
#        Data
#       </b>
#       <b>
#        Scientists
#       </b>
#       analyze PlaceIQ hyperlocal
#       <b>
#        data
#       </b>
#       sources to develop accurate predictions of audience and behavior....
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        11 days ago
#       </span>
#       <span class="tt_set" id="tt_set_0">
#        -
#        <span class="savelink2" id="savelink2_5b8a65b6982893bf">
#         <a class="sl resultLink save-job-link" href="#" id="sj_5b8a65b6982893bf" onclick="changeJobState('5b8a65b6982893bf', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('5b8a65b6982893bf', 0, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_5b8a65b6982893bf" style="display:none;">
#       </div>
#       <script>
#        window['result_5b8a65b6982893bf'] = {"showSource": false, "source": "PlaceIQ", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "11 days ago","jobKey": "5b8a65b6982893bf", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_0" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_0">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Placeiq-l-New-York,-NY-jobs.html" rel="nofollow">
#            PlaceIQ jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Placeiq?fromjk=5b8a65b6982893bf&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=6ae0e4a8a0a337cd">
#            Placeiq
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Placeiq.html">
#            PlaceIQ
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="90283f5714b2f111" data-tn-component="organicJob" id="p_90283f5714b2f111" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_90283f5714b2f111">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=90283f5714b2f111&amp;fccid=a5b4499d9e91a5c6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">
#    Developer Programs Engineer, Machine Learning
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Google?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=90283f5714b2f111&amp;jcid=a5b4499d9e91a5c6" target="_blank">
#     Google
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Google/reviews?jcid=a5b4499d9e91a5c6" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Developer+Programs+Engineer%2C+Machine+Learning&amp;fromjk=90283f5714b2f111');" target="_blank" title="Google reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    4.3
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.800003px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    1,127 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10011
#     <span style="font-size: smaller">
#      (Chelsea area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Passionate people are everywhere at Google. In Developer Relations, we get excited to collaborate and connect with the communities that love technology as
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        6 days ago
#       </span>
#       <span class="tt_set" id="tt_set_1">
#        -
#        <span class="savelink2" id="savelink2_90283f5714b2f111">
#         <a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 1, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_90283f5714b2f111" style="display:none;">
#       </div>
#       <script>
#        window['result_90283f5714b2f111'] = {"showSource": false, "source": "Google", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "6 days ago","jobKey": "90283f5714b2f111", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_1" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('90283f5714b2f111'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_1">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Google-l-New-York,-NY-jobs.html" rel="nofollow">
#            Google jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Developer+Program+Engineer&amp;l1=New+York%2C+NY">
#            Developer Program Engineer salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Google?fromjk=90283f5714b2f111&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=a5b4499d9e91a5c6">
#            Google
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Google.html">
#            Google
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="0bffc15fa50ec9a4" data-tn-component="organicJob" id="p_0bffc15fa50ec9a4" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_0bffc15fa50ec9a4">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0bffc15fa50ec9a4&amp;fccid=302ac6eda058f71c" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="Internship: Sales &amp; Marketing Data Analysis">
#    Internship: Sales &amp; Marketing
#    <b>
#     Data
#    </b>
#    Analysis
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    JW Player
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10018
#     <span style="font-size: smaller">
#      (Clinton area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Ability to think abstractly and nontraditionally about
#       <b>
#        data
#       </b>
#       trends &amp; implications with an exceptional attention to detail....
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        13 days ago
#       </span>
#       <span class="tt_set" id="tt_set_2">
#        -
#        <span class="savelink2" id="savelink2_0bffc15fa50ec9a4">
#         <a class="sl resultLink save-job-link" href="#" id="sj_0bffc15fa50ec9a4" onclick="changeJobState('0bffc15fa50ec9a4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0bffc15fa50ec9a4', 2, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_0bffc15fa50ec9a4" style="display:none;">
#       </div>
#       <script>
#        window['result_0bffc15fa50ec9a4'] = {"showSource": false, "source": "JW Player", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "13 days ago","jobKey": "0bffc15fa50ec9a4", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_2" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_2">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Jw-Player-l-New-York,-NY-jobs.html" rel="nofollow">
#            JW Player jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Internship&amp;l1=New+York%2C+NY">
#            Internship salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Jw-Player?fromjk=0bffc15fa50ec9a4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=4539715bb20eb005">
#            Jw Player
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/cmp/Jw-Player.html">
#            JW Player
#           </a>
#           -
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="cd0799dfdf821b2c" data-tn-component="organicJob" id="p_cd0799dfdf821b2c" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_cd0799dfdf821b2c">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cd0799dfdf821b2c&amp;fccid=25b5166547bbf543" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Senior Inventive Scientist (Labs Big Data Research)">
#    Senior Inventive
#    <b>
#     Scientist
#    </b>
#    (Labs Big
#    <b>
#     Data
#    </b>
#    Research)
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/AT&amp;T?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=cd0799dfdf821b2c&amp;jcid=25b5166547bbf543" target="_blank">
#     AT&amp;T
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/AT&amp;T/reviews?jcid=25b5166547bbf543" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Senior+Inventive+Scientist+%28Labs+Big+Data+Research%29&amp;fromjk=cd0799dfdf821b2c');" target="_blank" title="AT&amp;T reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    3.9
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    13,439 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       <b>
#        Data
#       </b>
#       <b>
#        Scientists
#       </b>
#       will usually have a Master’s; Qualified candidates may be asked to submit a Research Statement (required for Inventive
#       <b>
#        Scientist
#       </b>
#       applicants) and...
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        2 days ago
#       </span>
#       <span class="tt_set" id="tt_set_3">
#        -
#        <span class="savelink2" id="savelink2_cd0799dfdf821b2c">
#         <a class="sl resultLink save-job-link" href="#" id="sj_cd0799dfdf821b2c" onclick="changeJobState('cd0799dfdf821b2c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cd0799dfdf821b2c', 3, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('cd0799dfdf821b2c'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_cd0799dfdf821b2c" style="display:none;">
#       </div>
#       <script>
#        window['result_cd0799dfdf821b2c'] = {"showSource": false, "source": "AT\x26T", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "2 days ago","jobKey": "cd0799dfdf821b2c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_3" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cd0799dfdf821b2c'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_3">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-AT&amp;T-l-New-York,-NY-jobs.html" rel="nofollow">
#            AT&amp;T jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Senior+Inventive+Scientist&amp;l1=New+York%2C+NY">
#            Senior Inventive Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/AT&amp;T?fromjk=cd0799dfdf821b2c&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=25b5166547bbf543">
#            AT&amp;T
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/AT%26T.html">
#            AT&amp;T
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="3ecaa294064ce9f0" data-tn-component="organicJob" id="p_3ecaa294064ce9f0" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_3ecaa294064ce9f0">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=3ecaa294064ce9f0&amp;fccid=fe2d21eef233e94a" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Data Scientist - NYC">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#    - NYC
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Amazon.com?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=3ecaa294064ce9f0&amp;jcid=12db64101709fb92" target="_blank">
#     Amazon Web Services, Inc.
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Amazon.com/reviews?jcid=12db64101709fb92" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+-+NYC&amp;fromjk=3ecaa294064ce9f0');" target="_blank" title="Amazon Web Services reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    3.7
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.2px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    8,557 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Interested in creating new state-of-the-art solutions using Machine Learning and
#       <b>
#        Data
#       </b>
#       Mining techniques on Terabytes of
#       <b>
#        Data
#       </b>
#       ?...
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="result-link-source">
#        Amazon.com
#       </span>
#       -
#       <span class="date">
#        10 days ago
#       </span>
#       <span class="tt_set" id="tt_set_4">
#        -
#        <span class="savelink2" id="savelink2_3ecaa294064ce9f0">
#         <a class="sl resultLink save-job-link" href="#" id="sj_3ecaa294064ce9f0" onclick="changeJobState('3ecaa294064ce9f0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('3ecaa294064ce9f0', 4, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('3ecaa294064ce9f0'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_3ecaa294064ce9f0" style="display:none;">
#       </div>
#       <script>
#        window['result_3ecaa294064ce9f0'] = {"showSource": true, "source": "Amazon.com", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "10 days ago","jobKey": "3ecaa294064ce9f0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_4" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('3ecaa294064ce9f0'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_4">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/jobs?q=Amazon+Web+Services,+Inc&amp;l=New+York,+NY&amp;nc=jasx" rel="nofollow">
#            Amazon Web Services, Inc. jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Amazon.com?fromjk=3ecaa294064ce9f0&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=12db64101709fb92">
#            Amazon Web Services, Inc.
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="235f3afdc8453fc0" data-tn-component="organicJob" id="p_235f3afdc8453fc0" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_235f3afdc8453fc0">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=235f3afdc8453fc0&amp;fccid=f7029f63fe5c906e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Verizon?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=235f3afdc8453fc0&amp;jcid=f7029f63fe5c906e" target="_blank">
#     Verizon
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Verizon/reviews?jcid=f7029f63fe5c906e" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=235f3afdc8453fc0');" target="_blank" title="Verizon reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    3.9
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    10,531 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10007
#     <span style="font-size: smaller">
#      (Financial District area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <a class="more_loc" href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;rbt=Data+Scientist&amp;rbc=Verizon&amp;jtid=1872a3288ede048a&amp;jcid=f7029f63fe5c906e&amp;grp=tcl" onmousedown="ptk('addlloc');" rel="nofollow">
#   +2 locations
#  </a>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       Research
#       <b>
#        data
#       </b>
#       to improve customer engagement. Understand, categorize, organize, and interpret heterogeneous
#       <b>
#        data
#       </b>
#       sets....
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        14 days ago
#       </span>
#       <span class="tt_set" id="tt_set_5">
#        -
#        <span class="savelink2" id="savelink2_235f3afdc8453fc0">
#         <a class="sl resultLink save-job-link" href="#" id="sj_235f3afdc8453fc0" onclick="changeJobState('235f3afdc8453fc0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('235f3afdc8453fc0', 5, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_235f3afdc8453fc0" style="display:none;">
#       </div>
#       <script>
#        window['result_235f3afdc8453fc0'] = {"showSource": false, "source": "Verizon", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 days ago","jobKey": "235f3afdc8453fc0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_5" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_5">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Verizon-l-New-York,-NY-jobs.html" rel="nofollow">
#            Verizon jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Verizon?fromjk=235f3afdc8453fc0&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=f7029f63fe5c906e">
#            Verizon
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/cmp/Verizon.html">
#            Verizon
#           </a>
#           -
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="cabdf8ddc92e8eca" data-tn-component="organicJob" id="p_cabdf8ddc92e8eca" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_cabdf8ddc92e8eca">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cabdf8ddc92e8eca&amp;fccid=21c72fd5fe6c8641" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Scientist">
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    x.ai
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10004
#     <span style="font-size: smaller">
#      (Financial District area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       A
#       <b>
#        Data
#       </b>
#       <b>
#        Scientist
#       </b>
#       will. Familiar with
#       <b>
#        data
#       </b>
#       structures, parallelism and concurrency. Be capable of visualizing and communicating
#       <b>
#        data
#       </b>
#       science concepts to other...
#      </span>
#     </div>
#     <div class="iaP">
#      <span class="iaLabel">
#       Easily apply
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        17 days ago
#       </span>
#       <span class="tt_set" id="tt_set_6">
#        -
#        <span class="savelink2" id="savelink2_cabdf8ddc92e8eca">
#         <a class="sl resultLink save-job-link" href="#" id="sj_cabdf8ddc92e8eca" onclick="changeJobState('cabdf8ddc92e8eca', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cabdf8ddc92e8eca', 6, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('cabdf8ddc92e8eca'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_cabdf8ddc92e8eca" style="display:none;">
#       </div>
#       <script>
#        window['result_cabdf8ddc92e8eca'] = {"showSource": false, "source": "x.ai", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "17 days ago","jobKey": "cabdf8ddc92e8eca", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_6" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cabdf8ddc92e8eca'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_6">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-X-Ai-l-New-York,-NY-jobs.html" rel="nofollow">
#            x.ai jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">
#            Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/X.ai?fromjk=cabdf8ddc92e8eca&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=808eeee045d402b4">
#            X.ai
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="0e486be090f66c4e" data-tn-component="organicJob" id="p_0e486be090f66c4e" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_0e486be090f66c4e">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0e486be090f66c4e&amp;fccid=9044e8bd254c73d6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Security Data Scientist">
#    Security
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    Rockstar New York
#   </span>
#  </span>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       The successful candidate will both define
#       <b>
#        data
#       </b>
#       which should be captured in future states and analyze existing
#       <b>
#        data
#       </b>
#       in order to isolate patterns of bad activity....
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        1 day ago
#       </span>
#       <span class="tt_set" id="tt_set_7">
#        -
#        <span class="savelink2" id="savelink2_0e486be090f66c4e">
#         <a class="sl resultLink save-job-link" href="#" id="sj_0e486be090f66c4e" onclick="changeJobState('0e486be090f66c4e', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0e486be090f66c4e', 7, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('0e486be090f66c4e'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_0e486be090f66c4e" style="display:none;">
#       </div>
#       <script>
#        window['result_0e486be090f66c4e'] = {"showSource": false, "source": "Rockstar New York", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "1 day ago","jobKey": "0e486be090f66c4e", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_7" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0e486be090f66c4e'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_7">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Rockstar-New-York-l-New-York,-NY-jobs.html" rel="nofollow">
#            Rockstar New York jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Security+Data+Scientist&amp;l1=New+York%2C+NY">
#            Security Data Scientist salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Rockstar-New-York.html">
#            Rockstar New York
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# <div class=" row result" data-jk="39466464fb7cb366" data-tn-component="organicJob" id="p_39466464fb7cb366" itemscope="" itemtype="http://schema.org/JobPosting">
#  <h2 class="jobtitle" id="jl_39466464fb7cb366">
#   <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=39466464fb7cb366&amp;fccid=fe404d18bb9eef1e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Research Lead / Data Scientist">
#    Research Lead /
#    <b>
#     Data
#    </b>
#    <b>
#     Scientist
#    </b>
#   </a>
#  </h2>
#  <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
#   <span itemprop="name">
#    <a href="/cmp/Spotify?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=39466464fb7cb366&amp;jcid=fe404d18bb9eef1e" target="_blank">
#     Spotify
#    </a>
#   </span>
#  </span>
#  -
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Spotify/reviews?jcid=fe404d18bb9eef1e" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Research+Lead+%5C%2F+Data+Scientist&amp;fromjk=39466464fb7cb366');" target="_blank" title="Spotify reviews">
#   <span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">
#    4.6
#   </span>
#   <span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;">
#    <span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 54.6px;">
#     <!-- -->
#    </span>
#   </span>
#   <span class="slNoUnderline">
#    10 reviews
#   </span>
#  </a>
#  -
#  <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place">
#   <span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress">
#    <span itemprop="addressLocality">
#     New York, NY 10011
#     <span style="font-size: smaller">
#      (Chelsea area)
#     </span>
#    </span>
#   </span>
#  </span>
#  <table border="0" cellpadding="0" cellspacing="0">
#   <tr>
#    <td class="snip">
#     <div>
#      <span class="summary" itemprop="description">
#       You have experience with a range of
#       <b>
#        data
#       </b>
#       science techniques including clustering, machine learning, and network analysis....
#      </span>
#     </div>
#     <div class="result-link-bar-container">
#      <div class="result-link-bar">
#       <span class="date">
#        29 days ago
#       </span>
#       <span class="tt_set" id="tt_set_8">
#        -
#        <span class="savelink2" id="savelink2_39466464fb7cb366">
#         <a class="sl resultLink save-job-link" href="#" id="sj_39466464fb7cb366" onclick="changeJobState('39466464fb7cb366', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">
#          save job
#         </a>
#        </span>
#        -
#        <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('39466464fb7cb366', 8, false); return false;">
#         email
#        </a>
#        -
#        <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('39466464fb7cb366'); return false;">
#         more...
#        </a>
#       </span>
#       <div class="edit_note_content" id="editsaved2_39466464fb7cb366" style="display:none;">
#       </div>
#       <script>
#        window['result_39466464fb7cb366'] = {"showSource": false, "source": "Spotify", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "29 days ago","jobKey": "39466464fb7cb366", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};
#       </script>
#      </div>
#     </div>
#     <div class="tab-container">
#      <div class="more-links-container result-tab" id="tt_display_8" style="display:none;">
#       <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('39466464fb7cb366'); return false;" title="Close">
#       </a>
#       <div class="more_actions" id="more_8">
#        <ul>
#         <li>
#          <span class="mat">
#           View all
#           <a href="/q-Spotify-l-New-York,-NY-jobs.html" rel="nofollow">
#            Spotify jobs in New York, NY
#           </a>
#           -
#           <a href="/l-New-York,-NY-jobs.html">
#            New York jobs
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Salary Search:
#           <a href="/salary?q1=Research+Lead&amp;l1=New+York%2C+NY">
#            Research Lead salaries in New York, NY
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Learn more about working at
#           <a href="/cmp/Spotify?fromjk=39466464fb7cb366&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=fe404d18bb9eef1e">
#            Spotify
#           </a>
#          </span>
#         </li>
#         <li>
#          <span class="mat">
#           Related forums:
#           <a href="/forum/loc/New-York-New-York.html">
#            New York, New York
#           </a>
#           -
#           <a href="/forum/cmp/Spotify.html">
#            Spotify
#           </a>
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="dya-container result-tab">
#      </div>
#      <div class="tellafriend-container result-tab email_job_content">
#      </div>
#      <div class="sign-in-container result-tab">
#      </div>
#      <div class="notes-container result-tab">
#      </div>
#     </div>
#    </td>
#   </tr>
#  </table>
# </div>
#
# [u'New York, NY']

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %%
print soupIndeed.prettify()[0:1000]

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %%
## YOUR CODE HERE

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
YOUR_CITY = ''

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', YOUR_CITY]):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results
        pass

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
## YOUR CODE HERE

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
